# %% [markdown]
# # Tarefa 03
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os Tutores
# - Divirta-se :)

# %%
import pandas as pd
import requests

# %% [markdown]
# ####  1) Lendo de APIs
# Vimos em aula como carregar dados públicos do governo através de um API (*Application Programming Interface*). No exemplo de aula, baixamos os dados de pedidos de verificação de limites (PVL) realizados por estados, e selecionamos apenas aqueles referentes ao estado de São Paulo.
#
# 1. Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.
# 2. Quais são os três *status* das solicitações mais frequentes na base? Quais são suas frequências?
# 3. Construa uma nova variável que contenha o ano do **status**. Observe que ```data_status``` vem como tipo *object* no **DataFrame**. Dica: você pode usar o método ```.str``` para transformar o tipo da variável em string, em seguida um método como [**slice()**](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.slice.html) ou [**split()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).
# 4. Indique a frequência de cada ano do campo construído no item (3).

# %%
# 1) Seu código aqui
import pandas as pd
import requests

url = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl'

# %%
# 2) Seu código aqui
r = requests.get(url)

r.status_code
# Out:
# 200

# %%
data_json = r.json()

print(data_json['items'])
# Out:
# [{'id_pleito': 28088, 'tipo_interessado': 'Município', 'interessado': 'Rio Bonito do Iguaçu', 'cod_ibge': 4122156, 'uf': 'PR', 'num_pvl': 'PVL02.000690/2018-14', 'status': 'Deferido (PVL-IF)', 'num_processo': None, 'data_protocolo': None, 'tipo_operacao': 'Operação contratual interna', 'finalidade': 'Infraestrutura', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Agência de Fomento do Paraná S/A', 'moeda': 'Real', 'valor': 2000000, 'pvl_assoc_divida': 0, 'pvl_contradado_credor': 1, 'data_status': '15/05/2018'}, {'id_pleito': 26585, 'tipo_interessado': 'Município', 'interessado': 'Inimutaba', 'cod_ibge': 3131109, 'uf': 'MG', 'num_pvl': 'PVL02.002239/2017-51', 'status': 'Deferido', 'num_processo': '17944.102546/2017-01', 'data_protocolo': '2017-11-28T15:01:37Z', 'tipo_operacao': 'Operação contratual interna', 'finalidade': 'Infraestrutura', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Banco de Desenvolvimento de Minas Gerais S/A', 'moeda': 'Real', 'valor':
# ...

# %%
data_frame_gov = pd.DataFrame(data_json['items'])

data_frame_gov
# Out:
#       id_pleito tipo_interessado              interessado  cod_ibge  uf  \
# 0         28088        Município     Rio Bonito do Iguaçu   4122156  PR
# 1         26585        Município                Inimutaba   3131109  MG
# 2         26587        Município                  Coimbra   3116704  MG
# 3         27889        Município  Espírito Santo do Turvo   3515194  SP
# 4         26545        Município                  Berizal   3106655  MG
# ...         ...              ...                      ...       ...  ..
# 4995      24807        Município       Faxinal dos Guedes   4205308  SC
# 4996      21548        Município            Florianópolis   4205407  SC
# 4997      13246        Município       Primavera do Leste   5107040  MT
# 4998      13250        Município            Iguaba Grande   3301876  RJ
# 4999      14230        Município               Ituporanga   4208500  SC
#
#                    num_pvl                          status  \
# ...

# %%
data_frame_gov['uf'].value_counts()
# Out:
# uf
# PR    1024
# MG     904
# RS     747
# SC     600
# SP     590
# BA     240
# GO      97
# MT      87
# CE      82
# MS      71
# RJ      61
# PE      60
# ES      55
# TO      53
# RN      41
# PI      40
# PA      39
# RO      37
# MA      34
# PB      32
# AL      27
# AM      23
# SE      23
# DF      14
# AC       7
# AP       6
# RR       6
# Name: count, dtype: int64

# %%
pvlRio = data_frame_gov.loc[data_frame_gov['uf'] == 'RJ']

pvlRio
# Out:
#       id_pleito tipo_interessado           interessado  cod_ibge  uf  \
# 182       10637        Município           Teresópolis   3305802  RJ
# 239       26368        Município        Rio de Janeiro   3304557  RJ
# 460       10136        Município                Tanguá   3305752  RJ
# 461       10142        Município  Cachoeiras de Macacu   3300803  RJ
# 503       10230        Município               Resende   3304201  RJ
# ...         ...              ...                   ...       ...  ..
# 4627      10266        Município    Armação dos Búzios   3300233  RJ
# 4746      10095        Município        Angra dos Reis   3300100  RJ
# 4857      12870        Município               Niterói   3303302  RJ
# 4925      44855        Município             Vassouras   3306206  RJ
# 4998      13250        Município         Iguaba Grande   3301876  RJ
#
#                    num_pvl                                             status  \
# ...

# %%
pvlRio['status'].value_counts()
# Out:
# status
# Deferido                                                 20
# Arquivado                                                12
# Encaminhado à PGFN com manifestação técnica favorável     9
# Arquivado por decurso de prazo                            8
# Deferido (PVL-IF)                                         4
# Regularizado                                              3
# Arquivado a pedido                                        3
# Assinado pelo interessado (retificação)                   1
# Em retificação pelo interessado                           1
# Name: count, dtype: int64

# %%
status_counts = pvlRio['status'].value_counts()

top_3_status = status_counts.head(3)

print(top_3_status)
# Out:
# status
# Deferido                                                 20
# Arquivado                                                12
# Encaminhado à PGFN com manifestação técnica favorável     9
# Name: count, dtype: int64

# %%
data_frame_gov['data_status'] = data_frame_gov['data_status'].astype(str)

data_frame_gov['ano_status'] = data_frame_gov['data_status'].str.slice(0, 4)

pd.DataFrame(data_frame_gov)
# Out:
#       id_pleito tipo_interessado              interessado  cod_ibge  uf  \
# 0         28088        Município     Rio Bonito do Iguaçu   4122156  PR
# 1         26585        Município                Inimutaba   3131109  MG
# 2         26587        Município                  Coimbra   3116704  MG
# 3         27889        Município  Espírito Santo do Turvo   3515194  SP
# 4         26545        Município                  Berizal   3106655  MG
# ...         ...              ...                      ...       ...  ..
# 4995      24807        Município       Faxinal dos Guedes   4205308  SC
# 4996      21548        Município            Florianópolis   4205407  SC
# 4997      13246        Município       Primavera do Leste   5107040  MT
# 4998      13250        Município            Iguaba Grande   3301876  RJ
# 4999      14230        Município               Ituporanga   4208500  SC
#
#                    num_pvl                          status  \
# ...

# %%
df_frequencia_anos = data_frame_gov['ano_status'].value_counts().reset_index()

df_frequencia_anos.columns = ['ano_status', 'frequencia']

df_frequencia_anos = df_frequencia_anos.sort_values(by='ano_status').reset_index(drop=True)

pd.DataFrame(df_frequencia_anos)
# Out:
#    ano_status  frequencia
# 0        01/0          76
# 1        01/1          19
# 2        02/0         111
# 3        02/1          32
# 4        03/0         106
# ..        ...         ...
# 57       29/1          66
# 58       30/0         201
# 59       30/1          74
# 60       31/0          76
# 61       31/1          24
#
# [62 rows x 2 columns]

# %% [markdown]
# ####  2) Melhorando a interação com o API
# Observe dois URLs de consultas diferentes, por exemplo o URL utilizado em aula, e o URL feito no exercício anterior. Compare-os e observe as diferenças.
#
# 1. Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado (```'Estado'```ou ```Município```), e que devolve os dados da consulta no formato *DataFrame*.
# 2. Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com *status* em 'Arquivado por decurso de prazo' estão registradas?
# 3. Qual é o município da Bahia com mais solicitações deferidas?
# 4. Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

# %%
#1) Seu código aqui

consulta_df = data_frame_gov[['uf', 'interessado']]

pd.DataFrame(consulta_df)
# Out:
#       uf              interessado
# 0     PR     Rio Bonito do Iguaçu
# 1     MG                Inimutaba
# 2     MG                  Coimbra
# 3     SP  Espírito Santo do Turvo
# 4     MG                  Berizal
# ...   ..                      ...
# 4995  SC       Faxinal dos Guedes
# 4996  SC            Florianópolis
# 4997  MT       Primavera do Leste
# 4998  RJ            Iguaba Grande
# 4999  SC               Ituporanga
#
# [5000 rows x 2 columns]

# %%
# 2) Seu código aqui

df_filtrado = data_frame_gov[(data_frame_gov['uf'] == 'MG') & 
                           (data_frame_gov['tipo_interessado'] == 'Estado') & 
                           (data_frame_gov['status'] == 'Arquivado por decurso de prazo')]


numero_solicitacoes = df_filtrado.shape[0]

print(f"Número de solicitações para Minas Gerais com status 'Arquivado por decurso de prazo': {numero_solicitacoes}")
# Out:
# Número de solicitações para Minas Gerais com status 'Arquivado por decurso de prazo': 0

# %%
# 3) Seu código aqui
munBA = data_frame_gov.loc[data_frame_gov['uf'] == 'BA']

munBA
# Out:
#       id_pleito tipo_interessado               interessado  cod_ibge  uf  \
# 58        28674        Município                   Central   2907608  BA
# 62        31491        Município                   Brejões   2904308  BA
# 75        31139        Município                    Pindaí   2924504  BA
# 100       27331        Município              Castro Alves   2907301  BA
# 104       32608        Município                   Brumado   2904605  BA
# ...         ...              ...                       ...       ...  ..
# 4901       8897        Município  Presidente Jânio Quadros   2925709  BA
# 4953      18983        Município      Formosa do Rio Preto   2911105  BA
# 4969      18544        Município                 Itamaraju   2915601  BA
# 4988      12312        Município     Governador Mangabeira   2911600  BA
# 4992      12780        Município               Serra Preta   2930402  BA
#
#                    num_pvl              status          num_processo  \
# ...

# %%
# 4) Seu código aqui

munBA_deferido = munBA[munBA['status'] == 'Deferido']

municipio_counts = munBA_deferido['interessado'].value_counts()

municipio_mais_solicitacoes = municipio_counts.idxmax()
numero_solicitacoes = municipio_counts.max()

print(f"O município da Bahia com mais solicitações deferidas é {municipio_mais_solicitacoes} com {numero_solicitacoes} solicitações deferidas.")
# Out:
# O município da Bahia com mais solicitações deferidas é Bahia com 6 solicitações deferidas.

# %%
munBA_estado = munBA[(munBA['uf'] == 'BA') & (munBA['tipo_interessado'] == 'Estado')]
munBA_estado.to_csv('solicitacoes_bahia_estado.csv', index=False)

print("Arquivo CSV com os dados de solicitações da Bahia e tipo 'Estado' foi salvo como 'solicitacoes_bahia_estado.csv'.")
# Out:
# Arquivo CSV com os dados de solicitações da Bahia e tipo 'Estado' foi salvo como 'solicitacoes_bahia_estado.csv'.
